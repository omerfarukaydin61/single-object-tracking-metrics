# %%
import pandas as pd
df = pd.read_csv('results.csv')
# sort by 'Averahe IoU' 
df = df.sort_values(by='Average IoU', ascending=False, ignore_index=True)
df
# Out:
#                                        Name  Average IoU  Precision  \
# 0    yolo_botsort_tracker-trimmed-person-10     0.911867   0.934347
# 1    yolo_botsort_tracker-trimmed-person-10     0.911839   0.934347
# 2          mmtracking_vis-trimmed-person-10     0.884765   0.889512
# 3  yolo_bytetrack_tracker-trimmed-person-10     0.876317   0.936216
# 4  yolo_bytetrack_tracker-trimmed-person-10     0.876308   0.936483
# 5                     ssd-trimmed-person-10     0.606335   0.393114
# 6          mmtracking_sot-trimmed-person-10     0.480833   0.353883
#
#    Success Rate  Video Duration  Video FPS  Total Process Time  Total Frames  \
# 0      1.000000           124.9       30.0          353.392513        3747.0
# 1      1.000000           124.9       30.0           76.307620        3747.0
# 2      0.998399           124.9       30.0           64.333327        3747.0
# 3      0.999466           124.9       30.0          274.123571        3747.0
# ...
